# %% [markdown]
# <a href="https://colab.research.google.com/github/lilamil/amil1/blob/main/%D0%BB%D0%B0%D0%B1_5_(%D0%A8%D0%B0%D1%80%D0%B0%D1%84%D0%B5%D0%B5%D0%B2_%D0%90%D0%BC%D0%B8%D0%BB%D1%8C).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Локальный репозиторий

# %% [markdown]
# 1. Инициализация нового локального репозитория - git init![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Добавление файлов в индекс для коммита - git add <file>
# 3.Создание нового коммита - git commit -m "Commit message"
# 4. Просмотр истории коммитов - git log
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Просмотр изменений в файлах перед коммитом - git diff
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. Откат изменений в файле до предыдущего коммита - git checkout -- <file>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7. Создание новой ветки - git branch <branch_name>
# 8. Переключение между ветками - git checkout <branch_name>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 9. Слияние веток - git merge '<branch_name>'
# 10. Удаление ветки - git branch -d '<branch_name>'
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 11. Изменение сообщения последнего коммита - git amend
# 12. Удаление файла из репозитория и истории коммитов - git rm
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 13. Игнорирование файлов и папок с помощью .gitignore - создание и редактирование файла .gitignore![image.png](data:image/png;base64,...)

# %% [markdown]
# 14. Просмотр различий между ветками - git diff![image.png](data:image/png;base64,...)

# %% [markdown]
# 15. Отмена изменений в файле после добавления в индекс - git reset HEAD <file>
# 16. Просмотр информации о состоянии репозитория - git status
# 17. Переименование файлов - git mv <old_file> <new_file>![image.png](data:image/png;base64,...)

# %% [markdown]
# 18. Отображение информации о коммите - git show
# 19. Возврат к определенному коммиту - git checkout![image.png](data:image/png;base64,...)

# %% [markdown]
# 20. Создание и применение патчей - git format-patch и git apply
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 21. Изменение порядка коммитов - git rebase -i![image.png](data:image/png;base64,...)

# %% [markdown]
# 22. Изменение авторства коммитов - git commit --amend --author="Author Name <email>"![image.png](data:image/png;base64,...)

# %% [markdown]
# 23. Изменение истории коммитов с помощью rebase - git rebase![image.png](data:image/png;base64,...)

# %% [markdown]
# 24. Использование stash для временного сохранения изменений - git stash и git stash apply![image.png](data:image/png;base64,...)

# %% [markdown]
# 25. Применение изменений из одной ветки в другую с помощью cherry-pick - git cherry-pick <commit_id>![image.png](data:image/png;base64,...)

# %% [markdown]
# 26. Просмотр информации о ветках и удаленных репозиториях - git branch, git remote -v![image.png](data:image/png;base64,...)

# %% [markdown]
# 27. Изменение URL удаленного репозитория![image.png](data:image/png;base64,...)

# %% [markdown]
# 28. Удаление коммитов из истории![image.png](data:image/png;base64,...)

# %% [markdown]
# 29. Использование алиасов для команд Git - git config --global alias.<alias_name> "<command>"![image.png](data:image/png;base64,...)

# %% [markdown]
# 30. Использование подмодулей для работы с вложенными репозиториями - git submodule

# %% [markdown]
# ## УДАЛЕННЫЙ РЕПОЗИТОРИЙ

# %% [markdown]
# 1. Клонировать удаленный репозиторий на локальную машину
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Добавить новый удаленный репозиторий в существующий проект. (git remote add)![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Посмотреть список удаленных репозиториев, связанных с локальным проектом. (git remote -v)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Посмотреть информацию о удаленном репозитории (например, URL). (git remote show)![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Изменить URL удаленного репозитория. (git remote set-url)![image.png](data:image/png;base64,...)

# %% [markdown]
# 6. Добавить новый файл в удаленный репозиторий. (git add, git commit, git push)
# 7. Закоммитить изменения и отправить их в удаленный репозиторий. (git commit, git push)![image.png](data:image/png;base64,...)

# %% [markdown]
# 8. Посмотреть различия между локальным и удаленным репозиториями. (git diff, git difftool)![image.png](data:image/png;base64,...)

# %% [markdown]
# 9. Получить изменения из удаленного репозитория на локальную машину. (git fetch, git pull)![image.png](data:image/png;base64,...)

# %% [markdown]
# 10. Отправить ветку в удаленный репозиторий. (git push)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 11. Удалить ветку из удаленного репозитория. (git push origin --delete)
# 12. Переименовать удаленную ветку. (git branch -m, git push origin :old_branch_name new_branch_name)
# 13. Переместить удаленную ветку. (git push origin :branch_name destination_branch_name)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 14. Создать тэг и отправить его в удаленный репозиторий
# 15. Удалить тэг из удаленного репозитория![image.png](data:image/png;base64,...)

# %% [markdown]
# 16. Просмотреть историю коммитов на удаленном репозитории. (git log, gitk, gitg)
# 17. Отменить последний коммит и отправить изменения в удаленный репозиторий. (git reset, git push -f)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 18. Просмотреть информацию о ветках на удаленном репозитории. (git branch -r)![image.png](data:image/png;base64,...)

# %% [markdown]
# 19. Изменить настройки удаленного репозитория
# 20. Поделиться ссылкой![image.png](data:image/png;base64,...)

# %% [markdown]
# 22. Изменить права доступа
# 23. Посмотреть список вкладчиков![image.png](data:image/png;base64,...)

# %% [markdown]
# 24. Изменить сообщение последнего коммита и отправить изменения в удаленный репозиторий. (git commit --amend, git push -f)![image.png](data:image/png;base64,...)

# %% [markdown]
# 25. Сравнить различия между локальной и удаленной веткой. (git diff, git difftool)![image.png](data:image/png;base64,...)

# %% [markdown]
# 26. Удалить файл из удаленного репозитория. (git rm, git commit, git push)![image.png](data:image/png;base64,...)

# %% [markdown]
# 27. Восстановить удаленный файл из истории удаленного репозитория. (git checkout)![image.png](data:image/png;base64,...)

# %% [markdown]
# 28. Создать новую ветку на удаленном репозитории. (git push origin new_branch)
# 29. Просмотреть список тегов на удаленном репозитории. (git tag, git show)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 30. Сравнить различия между разными версиями удаленного репозитория![image.png](data:image/png;base64,...)

# %% [markdown]
# 31. Изменить сообщение отправленного коммита![image.png](data:image/png;base64,...)

# %% [markdown]
# 32. Отменить последний коммит, но оставить изменения в рабочей директории. (git reset --soft HEAD^)![image.png](data:image/png;base64,...)

# %% [markdown]
# 33. Переименовать файл, отправить изменения![image.png](data:image/png;base64,...)

# %% [markdown]
# 34. Отправить информацию об удаленном репозитории![image.png](data:image/png;base64,...)

# %% [markdown]
# 35. Удалить ветку на удаленном репозитории. (git push origin --delete branch_name)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 36. Просмотреть список изменений, ожидающих отправки в удаленный репозиторий. (git status)![image.png](data:image/png;base64,...)

# %% [markdown]
# 37. Отменить локальные изменения и обновить содержимое файлов до последней версии из удаленного репозитория. (git checkout -- <file>, git fetch, git reset --hard origin/<branch>)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 38. Переключиться на другую ветку и обновить содержимое до последней версии из удаленного репозитория. (git checkout <branch>, git pull)![image.png](data:image/png;base64,...)
